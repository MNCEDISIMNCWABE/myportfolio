# %%
import streamlit as st
import pandas as pd
import numpy as np
def generate_dummy_data(num_records=100):
    """Generate dummy data for testing purposes."""
    np.random.seed(42)
    data = {
        "full_name": [f"Candidate {i}" for i in range(1, num_records + 1)],
        "country": np.random.choice(["USA", "UK", "Canada", "Australia", "Germany", "France", "Japan", "India", "Brazil", "South Africa"], num_records),
        "country_full_name": np.random.choice(["United States", "United Kingdom", "Canada", "Australia", "Germany", "France", "Japan", "India", "Brazil", "South Africa"], num_records),
        "province": np.random.choice(["California", "Texas", "New York", "Florida", "Ontario", "Quebec", "New South Wales", "Victoria", "Bavaria", "Hesse", "Île-de-France", "Provence-Alpes-Côte d'Azur", "Tokyo", "Osaka", "Maharashtra", "Karnataka", "São Paulo", "Rio de Janeiro", "Gauteng", "Western Cape"], num_records),
        "city": np.random.choice(["New York", "Los Angeles", "Chicago", "Houston", "London", "Manchester", "Toronto", "Vancouver", "Sydney", "Melbourne", "Berlin", "Munich", "Paris", "Lyon", "Tokyo", "Osaka", "Mumbai", "Bangalore", "São Paulo", "Rio de Janeiro", "Johannesburg", "Cape Town"], num_records),
        "personal_emails": [f"candidate{i}@example.com" for i in range(1, num_records + 1)],
        "personal_numbers": [f"+123456789{i}" for i in range(1, num_records + 1)],
        "URL": [f"https://www.linkedin.com/in/candidate{i}" for i in range(1, num_records + 1)],
        "gender": np.random.choice(["Male", "Female", "Other"], num_records),
        "headline": np.random.choice(["Software Engineer", "Data Scientist", "Product Manager", "Marketing Specialist", "Financial Analyst", "HR Manager", "Sales Executive", "Graphic Designer", "Project Manager", "Consultant"], num_records),
        "summary": ["Summary for " + f"Candidate {i}" for i in range(1, num_records + 1)],
        "industry": np.random.choice(["Technology", "Finance", "Healthcare", "Education", "Retail", "Manufacturing", "Hospitality", "Construction", "Transportation", "Media"], num_records),
        "experiences": ["Experience for " + f"Candidate {i}" for i in range(1, num_records + 1)],
        "education": ["Education for " + f"Candidate {i}" for i in range(1, num_records + 1)],
        "skills": ["Skill1, Skill2, Skill3" for i in range(1, num_records + 1)],
        "certifications": ["Certification for " + f"Candidate {i}" for i in range(1, num_records + 1)],
        "languages": np.random.choice(["English", "Spanish", "French", "German", "Japanese", "Mandarin", "Hindi", "Portuguese", "Russian", "Arabic"], num_records)
    }
    return pd.DataFrame(data)

data = generate_dummy_data()
data
# Out:
#         full_name       country country_full_name                    province  \
# 0     Candidate 1         Japan    United Kingdom               Île-de-France
# 1     Candidate 2     Australia     United States                   Karnataka
# 2     Candidate 3         India             Japan                   Karnataka
# 3     Candidate 4       Germany             Japan                  California
# 4     Candidate 5         Japan             India                     Bavaria
# ..            ...           ...               ...                         ...
# 95   Candidate 96  South Africa             India                   São Paulo
# 96   Candidate 97        Brazil           Germany                   São Paulo
# 97   Candidate 98         Japan         Australia  Provence-Alpes-Côte d'Azur
# 98   Candidate 99        Brazil    United Kingdom                       Osaka
# 99  Candidate 100         India            France                      Quebec
#
# ...
