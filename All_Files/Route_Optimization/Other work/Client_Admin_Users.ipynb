# %%
# Send message to slack    
slack_credentials = 'https://hooks.slack.com/services/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'
title = f":rotating_light: Client Admin Users:"

import requests
from datetime import datetime
import datetime as dt
import time
import json
import warnings
warnings.filterwarnings("ignore")

start_time = datetime.now()
 
def post_to_slack(message,slack_credentials):
    data = { "icon_emoji": ":white_check_mark:",
             "attachments": [{"color": "#9733EE","fields": [{"title": title,"value": message,"short": "false"}]}]}
    url = slack_credentials
    requests.post(url, json=data, headers={'Content-Type': 'application/json'}, verify=True)


if __name__ == '__main__':
    try:
            
            import numpy as np
            import pandas as pd
            import datetime as dt
            from datetime import datetime
            import time
            import time
            from tqdm import tqdm
            import requests
            import json

            from google.oauth2.service_account import Credentials
            import pygsheets
            import googleapiclient
            import logging
            from oauth2client.service_account import ServiceAccountCredentials
            from google.oauth2 import service_account
            import gslides
            import warnings
            warnings.filterwarnings("ignore")

            import firebase_admin
            from firebase_admin import credentials, firestore
            #pip install google-api-core==1.32.0
            #pip install protobuf==3.15.5
            #pip install google-cloud-firestore==2.3.4


            ###>>>>>>>>>>>>>>>>>>>>>>>>>> Initialize Firebase client
            try:
                app = firebase_admin.get_app()
            except ValueError as e:
                cred = credentials.Certificate("C:/Users/leemn/OneDrive/Documents/Service Account/accountkey_firebase.json")
                firebase_admin.initialize_app(cred)
            db = firestore.client() 


            #>>>>>>>>>>>>>>>>>>>>>>>>>>> Pull Client Admin Users added in the last 14 days
            docs_dict = {}
            docs = db.collection(u'client-users').stream()

            for doc in docs:
                doc_dict = doc.to_dict()
                doc_dict['created_by'] = doc_dict['created_by'].path 
                docs_dict[doc.id] = doc_dict

            data = pd.DataFrame.from_dict(docs_dict,orient='index')
            data = data[['firstname','lastname','email','created_at','created_by','mobile_no']]
            data.reset_index(drop=True, inplace=True)
            data['date'] = data['created_at'].dt.date
            data = data[data.date >= dt.date.today() - pd.to_timedelta("14day")]
            data = data.drop('date',axis=1)

            #>>>>>>>>>>>>>>>>>>>>>>>>> Extract Client ID and map client name based on client ID
            def extract_ids(s):
                parts = s.split('/')
                return parts[1], parts[-1]

            data[['client_id', 'user_id']] = data['created_by'].apply(extract_ids).apply(pd.Series)

            data['client_name'] =     np.where( data['client_id'] == "zRpxC1kyh7ge4VlC0iu3" , "Ackermans Pharmacy"
                                    ,(np.where( data['client_id'] == "hy7Y3kxHgg0Q4KMSMyma" , "Aletts Rusks"
                                    ,(np.where( data['client_id'] == "r5Hb7LUqu0kk2Qd3AbB7" , "Andiccio24"
                                    ,(np.where( data['client_id'] == "yCVhIFW0V2WLbjTmY5tB" , "Aramex"
                                    ,(np.where( data['client_id'] == "NBinKwRfPr4vVbqZrupA" , "Belgotex"
                                    ,(np.where( data['client_id'] == "NsPHG9HCJw5Tgw4bVkUh" , "Busymed"
                                    ,(np.where( data['client_id'] == "CGTBlA89wEzDe3xyWjPy" , "Busymed Sandbox"
                                    ,(np.where( data['client_id'] == "tJxbNK75n4YJ6Oumro0k" , "Cowa-bunga Test Client"
                                    ,(np.where( data['client_id'] == "stY6CXv8mXmqF8hsVYeU" , "Digi Pharm"
                                    ,(np.where( data['client_id'] == "8YvhRBWGtTABrl6bhkjW" , "Dis-Chem Pharmacies"
                                    ,(np.where( data['client_id'] == "lnM4rxcp6uVTw8RhLTX9" , "EconoFoods"
                                    ,(np.where( data['client_id'] == "0C6fjhjLU6rnuoQyREOb" , "Geewiz"
                                    ,(np.where( data['client_id'] == "M4sdn7UTA9JkIPyzzS4P" , "JD Group"
                                    ,(np.where( data['client_id'] == "VCm2MFBrnAaMLQaImiJf" , "Kauai"
                                    ,(np.where( data['client_id'] == "yVRnsmD9Ajl1OQlkX6Sg" , "Kauai Sandbox"
                                    ,(np.where( data['client_id'] == "Ju2Ae08OZ83osvuIYkrs" , "Kristen's Kickass Icecream"
                                    ,(np.where( data['client_id'] == "KVo2gnuzWvPH4XQnJyN2" , "Loop Demo"
                                    ,(np.where( data['client_id'] == "xOCqjHDuWvkXnZAPeDFQ" , "Loop Logistics Test Client"
                                    ,(np.where( data['client_id'] == "n5DfgLRRxbvUejwtcRJH" , "Loop Test Client"
                                    ,(np.where( data['client_id'] == "Rh8sfJLs6NxNejo0PH1h" , "Loop Trial Sandbox"
                                    ,(np.where( data['client_id'] == "nO31bVSIrraBlWS15Thr" , "Nando's Qatar"
                                    ,(np.where( data['client_id'] == "FQmUHvoz3hcl5Ae44aW3" , "Nando's Botswana"
                                    ,(np.where( data['client_id'] == "Hw1dSXB6hEkoQ8HhYmNW" , "Nando’s Mauritius"
                                    ,(np.where( data['client_id'] == "zVznneXPn3Zaj75n5Q3N" , "Nando's SA"
                                    ,(np.where( data['client_id'] == "BUo9UTsiu29sMsID5CKC" , "Nando's SA Sandbox"
                                    ,(np.where( data['client_id'] == "ARIrLnDJ0TXBHjmPU5mG" , "OneCart"
                                    ,(np.where( data['client_id'] == "qiv6Z8eHY2AyC7Gazv3w" , "Parcel Ninja"
                                    ,(np.where( data['client_id'] == "OsyIw6UxAr94pXTKGFaU" , "Pizza Pasta Please"
                                    ,(np.where( data['client_id'] == "F50C6dDsBqiqw7S5SCFG" , "Quench"
                                    ,(np.where( data['client_id'] == "CQoCdzOEQZHAOE4k0b70" , "Quench Sandbox"
                                    ,(np.where( data['client_id'] == "gp316ncFwbEiv9UMuCYH" , "Ram"
                                    ,(np.where( data['client_id'] == "xrSHiB7rklASZSYz3LNR" , "Servest"
                                    ,(np.where( data['client_id'] == "Zl8DamSfvyNnKZYf3dhS" , "Somerset Timbers"
                                    ,(np.where( data['client_id'] == "1HkTWdBdgsKdBDjjIAYs" , "Spar"
                                    ,(np.where( data['client_id'] == "ZAvKuwk6zfbwsun8yZ3j" , "Test Client Prod"
                                    ,(np.where( data['client_id'] == "3Hm28GaJRBBIZByiZ9SA" , "The Delivery Company"
                                    ,(np.where( data['client_id'] == "JTutPYoTUX6QIr3RdPuD" , "The Local Choice"
                                    ,(np.where( data['client_id'] == "eEETls5ygWMXJ7JItyTG" , "The Local Sandbox"
                                    ,(np.where( data['client_id'] == "YriWOTYxdKOHT37RBg50" , "The Local Choice Waterstone & Heldervue Pharmacy"
                                    ,(np.where( data['client_id'] == "P6jlGGG6U4snbhmvt7Ca" , "Woolworths"
                                    ,(np.where( data['client_id'] == "TdyaJR64vgu6fIhp06SU" , "XLink"
                                    ,(np.where( data['client_id'] == "N9iBwT9x2ATYlD4kxwBT" , "Nology"
                                    ,(np.where( data['client_id'] == "TnxiIlI4yVUaLSRKtLWZ" , "Triangle truck"
                                    ,(np.where( data['client_id'] == "k36eLgmA3VsmJ937TD1W" , "Olivers Craft Logistics"
                                    ,(np.where( data['client_id'] == "K0i9ICblxGZfqOjM8kwU" , "Olivers Craft"
                                    ,(np.where( data['client_id'] == "4XMzzfQ4vkR0ELflNAAk" , "Cube Logistics"
                                    ,(np.where( data['client_id'] == "mYPoEBMCCuqJ0DIZ7yfM" , "Courier Guy Technicians"
                                    ,(np.where( data['client_id'] == "Q0wtTcXxdE3lSjHRppkH" , "Imperial Fast n Fresh"
                                    ,(np.where( data['client_id'] == "3PhF68sAYqajPyTwjlJi" , "Fastener Agencies"
                                    ,(np.where( data['client_id'] == "REvnJlwcn1cqJwvmLXmu" , "Yebo Fresh"
                                    ,(np.where( data['client_id'] == "k1RkaeTPoHqr8BWmgqE7" , "Burger & Brew"
                                    ,(np.where( data['client_id'] == "VARTjMf1gBEiVxrGNEmf" , "AM Couriers"
                                    ,(np.where( data['client_id'] == "B0l6eGBH0UB7wOhWzZ9J" , "WooliesDash"
                                    ,(np.where( data['client_id'] == "KHNmuax4WjaafWvTLmTg" , "Platinum Fuel"
                                    ,(np.where( data['client_id'] == "3Hm28GaJRBBIZByiZ9SA" , "The Delivery Co"
                                    ,(np.where( data['client_id'] == "OsyIw6UxAr94pXTKGFaU" , "P3", data['client_id']
                                    )))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))
                                    ))))))))))))))))))))))

            #>>>>>>>>>>>>>>>>>> Only the needed fields
            data = data[['firstname','lastname','email','mobile_no','created_at','client_name','client_id',]]


            #>>>>>>>>>>>>>>>>>>> Export to a google sheets file
            file = 'C:/Users/leemn/OneDrive/Documents/Service Account/cb-prod-297913-d207de781afd.json'
            sheet_id = '1L-udi8p7B8JfVsG1boYUzOmfvKgzT5V4amZ2S2EKIeg'
            sheet_name = 'Users'

            def write_to_gsheet(service_file_path, spreadsheet_id, sheet_name, data_df):
                gc = pygsheets.authorize(service_file=service_file_path)
                sh = gc.open_by_key(spreadsheet_id)
                try:
                    sh.add_worksheet(sheet_name)
                except:
                    pass
                wks_write = sh.worksheet_by_title(sheet_name)
                wks_write.clear('A1',None,'*')
                wks_write.set_dataframe(data_df, (1,1), encoding='utf-8', fit=True)
                wks_write.frozen_rows = 1
            write_to_gsheet(file, sheet_id, sheet_name, data) 
            
            # post message to slack
            post_to_slack(f"""
                      :white_check_mark: Successful!
                       Link: https://docs.google.com/spreadsheets/d/1L-udi8p7B8JfVsG1boYUzOmfvKgzT5V4amZ2S2EKIeg/edit?usp=sharing
                      
                       n_users_in_file: {data['email'].nunique()}
                       code_runtime: {round((datetime.now() - start_time).total_seconds(),3)} sec
                      """,slack_credentials)
    except:
        error_msg = f":warning: Oops, Error in the script!!!"
        post_to_slack(error_msg,slack_credentials)
