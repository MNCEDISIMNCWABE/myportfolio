# %%
#Importing the Nominatim geocoder class 
from geopy.geocoders import Nominatim
import pandas as pd
from geopy.extra.rate_limiter import RateLimiter
import urllib
import requests
from geopy.geocoders import GoogleV3
from geopy import distance
from numpy import radians, cos, sin, sqrt
from numpy import arcsin as asin


import csv
import pandas as pd
import googlemaps

from geopy.geocoders import GoogleV3

import pandas as pd
import numpy as np
import pandas_gbq
import pygsheets
from google.oauth2.service_account import Credentials
from oauth2client.service_account import ServiceAccountCredentials
from tqdm import tqdm
import time
import datetime as dt
# Multi-processing
from multiprocessing import Pool, cpu_count
import warnings
warnings.filterwarnings("ignore")

# %%
credentials = Credentials.from_service_account_file('C:/Users/leemn/Documents/Loop Service Account/cb-prod-297913-623cea238b9a.json')

# %%
query_orders = '''
SELECT trip_id, trip_client_id, driver.name AS driver_name, order_id, order_no,
branch.name AS branch_name, branch.address AS branch_address, 
branch.location.latitude AS branch_lat,
branch.location.longitude AS branch_lon,
customer.name AS customer_name,
customer_location.latitude AS customer_lat,
customer_location.longitude AS customer_lon,
delivery_distance,
created_at,
CASE
WHEN trip_client_id = "zRpxC1kyh7ge4VlC0iu3" THEN "Ackermans Pharmacy"
WHEN trip_client_id = "hy7Y3kxHgg0Q4KMSMyma" THEN "Aletts Rusks"
WHEN trip_client_id = "r5Hb7LUqu0kk2Qd3AbB7" THEN "Andiccio24"
WHEN trip_client_id = "yCVhIFW0V2WLbjTmY5tB" THEN "Aramex"
WHEN trip_client_id = "NBinKwRfPr4vVbqZrupA" THEN "Belgotex"
WHEN trip_client_id = "NsPHG9HCJw5Tgw4bVkUh" 
OR  trip_client_id = "OMRNyS6UcsFNObl2xcwe" THEN "Busymed"
--WHEN trip_client_id = "OMRNyS6UcsFNObl2xcwe" THEN "Cornerstone Pharmacy"
WHEN trip_client_id = "CGTBlA89wEzDe3xyWjPy" THEN "Busymed Sandbox"
WHEN trip_client_id = "tJxbNK75n4YJ6Oumro0k" THEN "Cowa-bunga Test Client"
WHEN trip_client_id = "stY6CXv8mXmqF8hsVYeU" THEN "Digi Pharm"
WHEN trip_client_id = "8YvhRBWGtTABrl6bhkjW" THEN "Dis-Chem Pharmacies"
WHEN trip_client_id = "lnM4rxcp6uVTw8RhLTX9" THEN "EconoFoods"
WHEN trip_client_id = "0C6fjhjLU6rnuoQyREOb" THEN "Geewiz"
WHEN trip_client_id = "M4sdn7UTA9JkIPyzzS4P" THEN "JD Group"
WHEN trip_client_id = "VCm2MFBrnAaMLQaImiJf" THEN "Kauai"
WHEN trip_client_id = "yVRnsmD9Ajl1OQlkX6Sg" THEN "Kauai Sandbox"
WHEN trip_client_id = "Ju2Ae08OZ83osvuIYkrs" THEN "Kristen's Kickass Icecream"
WHEN trip_client_id = "KVo2gnuzWvPH4XQnJyN2" THEN "Loop Demo"
WHEN trip_client_id = "xOCqjHDuWvkXnZAPeDFQ" THEN "Loop Logistics Test Client"
WHEN trip_client_id = "n5DfgLRRxbvUejwtcRJH" THEN "Loop Test Client"
WHEN trip_client_id = "Rh8sfJLs6NxNejo0PH1h" THEN "Loop Trial Sandbox"
WHEN trip_client_id = "nO31bVSIrraBlWS15Thr" THEN "Nando's Qatar"
WHEN trip_client_id = "FQmUHvoz3hcl5Ae44aW3" THEN "Nando's Botswana"
WHEN trip_client_id = "Hw1dSXB6hEkoQ8HhYmNW" THEN "Nando’s Mauritius"
WHEN trip_client_id = "zVznneXPn3Zaj75n5Q3N" THEN "Nando's SA"
WHEN trip_client_id = "BUo9UTsiu29sMsID5CKC" THEN "Nando's SA Sandbox"
WHEN trip_client_id = "ARIrLnDJ0TXBHjmPU5mG" THEN "OneCart"
WHEN trip_client_id = "qiv6Z8eHY2AyC7Gazv3w" THEN "Parcel Ninja"
WHEN trip_client_id = "OsyIw6UxAr94pXTKGFaU" THEN "Pizza Pasta Please"
WHEN trip_client_id = "F50C6dDsBqiqw7S5SCFG" THEN "Quench"
WHEN trip_client_id = "CQoCdzOEQZHAOE4k0b70" THEN "Quench Sandbox"
WHEN trip_client_id = "gp316ncFwbEiv9UMuCYH" THEN "Ram"
WHEN trip_client_id = "xrSHiB7rklASZSYz3LNR" THEN "Servest"
WHEN trip_client_id = "Zl8DamSfvyNnKZYf3dhS" THEN "Somerset Timbers"
WHEN trip_client_id = "1HkTWdBdgsKdBDjjIAYs" THEN "Spar"
WHEN trip_client_id = "ZAvKuwk6zfbwsun8yZ3j" THEN "Test Client Prod"
WHEN trip_client_id = "3Hm28GaJRBBIZByiZ9SA" THEN "The Delivery Company"
WHEN trip_client_id = "JTutPYoTUX6QIr3RdPuD" THEN "The Local Choice"
WHEN trip_client_id = "eEETls5ygWMXJ7JItyTG" THEN "The Local Sandbox"
WHEN trip_client_id = "YriWOTYxdKOHT37RBg50" THEN "The Local Choice Waterstone & Heldervue Pharmacy"
WHEN trip_client_id = "P6jlGGG6U4snbhmvt7Ca" THEN "Woolworths"
WHEN trip_client_id = "TdyaJR64vgu6fIhp06SU" THEN "XLink"
WHEN trip_client_id = "N9iBwT9x2ATYlD4kxwBT" THEN "Nology"
WHEN trip_client_id = "TnxiIlI4yVUaLSRKtLWZ" THEN "Triangle truck"
WHEN trip_client_id = "k36eLgmA3VsmJ937TD1W" THEN "Olivers Craft Logistics"
WHEN trip_client_id = "K0i9ICblxGZfqOjM8kwU" THEN "Olivers Craft"
WHEN trip_client_id = "4XMzzfQ4vkR0ELflNAAk" THEN "Cube Logistics"
WHEN trip_client_id = "mYPoEBMCCuqJ0DIZ7yfM" THEN "Courier Guy Technicians"
WHEN trip_client_id = "Q0wtTcXxdE3lSjHRppkH" THEN "Imperial Fast n Fresh"
WHEN trip_client_id = "3PhF68sAYqajPyTwjlJi" THEN "Fastener Agencies"
WHEN trip_client_id = "REvnJlwcn1cqJwvmLXmu" THEN "Yebo Fresh"
WHEN trip_client_id = "k1RkaeTPoHqr8BWmgqE7" THEN "Burger & Brew"
WHEN trip_client_id = "VARTjMf1gBEiVxrGNEmf" THEN "AM Couriers"
WHEN trip_client_id = "B0l6eGBH0UB7wOhWzZ9J" THEN "WooliesDash"
WHEN trip_client_id = "KHNmuax4WjaafWvTLmTg" THEN "Platinum Fuel"
WHEN trip_client_id = "3Hm28GaJRBBIZByiZ9SA" THEN "The Delivery Co"
WHEN trip_client_id = "OsyIw6UxAr94pXTKGFaU" THEN "P3"
END AS Client_Name
 FROM `cb-prod-297913.cb_prod_analytics.cb_end_orders_in_trip`
--WHERE trip_client_id IN ('TnxiIlI4yVUaLSRKtLWZ')
--AND trip_id IN ('kz9BD8j7ApR2cfhvspl4','B9ZimbYRzX4bOfhjxGcI')
ORDER BY trip_id

'''
df_orders = pd.read_gbq(query_orders, project_id='cb-prod-297913', dialect='standard', credentials=credentials,progress_bar_type='tqdm_notebook')
# Out:
# Downloading:   0%|          | 0/757813 [00:00<?, ?rows/s]

# %%
df_orders.head()
# Out:
#                 trip_id        trip_client_id        driver_name  \
# 0  000Jcnjd3OQ51AkzgiMq  zVznneXPn3Zaj75n5Q3N  Mpumelelo Nkandla
# 1  000cBQqqV4mwvaLNYjwa  zVznneXPn3Zaj75n5Q3N       Kazzy Kazzla
# 2  000jeXoJylm00mEojWdv  F50C6dDsBqiqw7S5SCFG  Partmose Mataruse
# 3  000uy5nZapODPCyiXgLJ  zVznneXPn3Zaj75n5Q3N    Moris Matsimela
# 4  001K9pj7Gjhnf2Fstk2I  zVznneXPn3Zaj75n5Q3N             Wesley
#
#                order_id          order_no   branch_name  \
# 0  Zgk1fspMEYoS2cjY8RAo              1941       Florida
# 1  iIdrAybjQkdhkjsOatEY              1558  Leaping Frog
# 2  gmhzHFchotuJyShjCr3p  1645518340326407     DC Cresta
# 3  crstIUWTIUe0vLw5Ba66              8412     Polokwane
# 4  B4ZviRCbcSwLiGMBmiDy              9709   Benoni Lake
#
#                                       branch_address  branch_lat  branch_lon  \
# 0  Cnr 9th Ave & Goldman St, Shop 21, Goldman Cro...  -26.177178   27.922963
# 1  Cnr Mulbarton Rd & William Nicol Dr Shop G053B...  -26.011157   28.011922
# ...

# %%
API_key = 'AIzaSyCkrolSwjpPGufcigton0eEL891nbAju-E'
client = googlemaps.Client(key=API_key)

# %%
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    # Radius of earth in kilometers is 6371
    km = 6371* c
    return km

df_orders['distance_optimized_km'] = df_orders.apply(lambda x:haversine(x['branch_lat'], x['branch_lon'], x['customer_lat'], x['customer_lon']), axis = 1)

# %%
df_orders['branch_lat'] = df_orders['branch_lat'].astype(str)
df_orders['branch_lon'] = df_orders['branch_lon'].astype(str)
df_orders['customer_lat'] = df_orders['customer_lat'].astype(str)
df_orders['customer_lon'] = df_orders['customer_lon'].astype(str)

df_orders['branch_geo'] = df_orders['branch_lat'] + ',' + df_orders['branch_lon']
df_orders['customer_geo'] = df_orders['customer_lat'] + ',' + df_orders['customer_lon']

# %%
def get_gmaps_distance(row):
    result = client.directions(str(row['branch_geo']), str(row['customer_geo']), mode='driving')
    distance = int(result[0]['legs'][0]['distance']['value']/ 1000)
    #duration = int(result[0]["legs"][0]["duration"]["value"]/60)
    return distance
    
df_orders["distance_normal_km"] = df_orders.apply(get_gmaps_distance, axis=1)

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trip_id                5 non-null      object
#  1   trip_client_id         5 non-null      object
#  2   driver_name            5 non-null      object
#  3   order_id               5 non-null      object
#  4   order_no               5 non-null      object
#  5   branch_name            5 non-null      object
#  6   branch_address         5 non-null      object
#  7   branch_lat             5 non-null      object
#  8   branch_lon             5 non-null      object
#  9   customer_name          5 non-null      object
#  10  customer_lat           5 non-null      object
#  11  customer_lon           5 non-null      object
#  12  delivery_distance      5 non-null      float64
#  13  created_at             5 non-null      datetime64[ns, UTC]
# ...

# %%
df_orders['difference_km'] = df_orders['distance_normal_km'] - df_orders['distance_optimized_km']
df_orders['minutes_saved'] = (df_orders['difference_km']/100)*60
df_orders['fuel_saved_litres'] = (df_orders['difference_km'])/13
df_orders['fuel_cost_saved'] = (df_orders['fuel_saved_litres'])*27.45
df_orders.head()
# Out:
#                 trip_id        trip_client_id    driver_name  \
# 0  B9ZimbYRzX4bOfhjxGcI  TnxiIlI4yVUaLSRKtLWZ  Victor.Mentis
# 1  B9ZimbYRzX4bOfhjxGcI  TnxiIlI4yVUaLSRKtLWZ  Victor.Mentis
# 2  kz9BD8j7ApR2cfhvspl4  TnxiIlI4yVUaLSRKtLWZ  Victor.Mentis
# 3  kz9BD8j7ApR2cfhvspl4  TnxiIlI4yVUaLSRKtLWZ  Victor.Mentis
# 4  kz9BD8j7ApR2cfhvspl4  TnxiIlI4yVUaLSRKtLWZ  Victor.Mentis
#
#                order_id   order_no                   branch_name  \
# 0  szks1GBQYwIZ96IpORqs      Tim 5  Trianlge Truck Hire main hub
# 1  1ZhS6vunMHvfp3B6kaus      Tim 3  Trianlge Truck Hire main hub
# 2  WSp24UsmhRpxmJtkhVmE   Victor 2  Trianlge Truck Hire main hub
# 3  rJOciXHqCz1PZyUIIVsE   Victor 1  Trianlge Truck Hire main hub
# 4  iwmbi47in8F1wZwJlLDs  Victor  3  Trianlge Truck Hire main hub
#
#                                       branch_address   branch_lat  branch_lon  \
# 0  10 Model Rd, Witfield, Boksburg, 1459, South A...  -26.1750081  28.2141246
# ...

# %%
# Export to google sheets
file = 'C:/Users/leemn/Documents/Loop Service Account/cb-prod-297913-623cea238b9a.json'
sheet_id = '1zZKS7ZFe0Q5ycObY5Kc-jrIysUL9fCWCdH-Yce8b5bA'
sheet_name = 'distances'

def write_to_gsheet(service_file_path, spreadsheet_id, sheet_name, data_df):
    gc = pygsheets.authorize(service_file=service_file_path)
    sh = gc.open_by_key(spreadsheet_id)
    try:
        sh.add_worksheet(sheet_name)
    except:
        pass
    wks_write = sh.worksheet_by_title(sheet_name)
    wks_write.clear('A1',None,'*')
    wks_write.set_dataframe(data_df, (1,1), encoding='utf-8', fit=True)
    wks_write.frozen_rows = 1

write_to_gsheet(file, sheet_id, sheet_name, df_orders)
