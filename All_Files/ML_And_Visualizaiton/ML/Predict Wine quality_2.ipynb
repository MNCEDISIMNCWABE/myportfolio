# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
wine = pd.read_csv('C:/Users/mncedisi.mncwabe/Documents/Practices/wine.csv')

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine.shape
# Out:
# (1599, 12)

# %%
# No missing values

wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# check the count of category of each wine quality
plt.figure(figsize = (10,6))
sns.countplot(x = 'quality',data=wine);

# %%
# Let's check the effect & distribution of each predictor variable on wine quality

plt.figure(figsize = (10,6))
sns.barplot(x='quality',y='fixed acidity',data = wine);

# %%
# fixed acidity doesn't give clear specification to classify wine

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='quality',y='volatile acidity',data = wine);

# %%
# volatile acidity decreases as the quality of wine increases
# meaning lower volatile acidity levels give better wine quality

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='quality',y='alcohol',data = wine);

# %%
# Higher levels of alcohol gives higher wine quality
# Alcohol also goes higher as the quality of wine increases

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='quality',y='citric acid',data = wine);

# %%
# Higher levels of citric acid gives higher wine quality
# Citric acid also goes higher as the quality of wine increases

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='quality',y='chlorides',data = wine);

# %%
# Chloride level decreases as the wine quality increases

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='quality',y='density',data = wine);

# %%
# desnity doesn't give any specification to classify wine

# %%
# let's check normality (distribution) of variables
plt.figure(figsize = (10,6))
sns.distplot(wine['density'],kde = True);

# %%
plt.figure(figsize = (10,6))
sns.distplot(wine['alcohol'],kde = True);

# %%
plt.figure(figsize = (10,6))
sns.distplot(wine['sulphates'],kde = True);

# %%
# Check the correlation of each predictor with the response variable

plt.figure(figsize=(12,6))
sns.heatmap(wine.corr(),cmap = plt.cm.RdYlBu_r, vmin = -0.25, annot = True, vmax = 0.6)
plt.title('Heatmap for correlations');

# %%
#  alcohol,fixed acidity,citric acid and sulphates have positive correlation with wine quality

# %%
# Lets categorize the groups of the wine quality to low,medium or high

quality = wine['quality'].values
category = []
for num in quality:
    if num < 5:
        category.append("Low")
    elif num > 6:
        category.append("High")
    else:
        category.append("Medium")

# %%
plt.figure(figsize = (10,7))
plot = sns.countplot(category, palette = "muted")
for p in plot.patches:
    plot.annotate(p.get_height(),(p.get_x() + p.get_width() / 2., p.get_height()), 
                  ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points');

# %%
from sklearn import metrics
import statsmodels.formula.api as smf
from sklearn import preprocessing


#Classification Algorithms 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import metrics
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score

# %%
# ------------------ Preprocessing Data for performing Machine learning algorithms-------------
# we should make binary classification for response variable
# by dividing wine as good and bad

bins = (2,6.5,8)
groups = ['bad','good']
wine['quality'] = pd.cut(wine['quality'],bins = bins,labels = groups)

# %%
# Now lets assign a labels to our quality variable i.e '0' for bad and '1' for good

le = LabelEncoder()
wine['quality'] = le.fit_transform(wine['quality'])

# %%
# count how many for '0' and '1'

wine['quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x = 'quality',data = wine);

# %%
#-------------Let's bulid Machine Learning Models----------

# first seperate the dataset as response variable (y) and feature variabes (X)

X = wine.drop('quality',axis = 1)
y = wine['quality']

# %%
# split the data

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 42)

# %%
# Now let's transform the train and test data using standard scaler

std = StandardScaler()
X_train = std.fit_transform(X_train)
X_test = std.fit_transform(X_test)

# %%
# Our train and test data is ready now to perform machine learning algorithm

# %%
# Random Forest

rf = RandomForestClassifier()
rf.fit(X_train,y_train)
rf.score(X_test,y_test)*100
# Out:
# 87.91666666666667

# %%
# Support Vector Classifier

svc = SVC()
svc.fit(X_train, y_train)
svc.score(X_test,y_test)*100
# Out:
# 88.125

# %%
# Neural Network

nnt = MLPClassifier()
nnt.fit(X_train,y_train)
nnt.score(X_test,y_test)*100
# Out:
# 87.91666666666667

# %%
# Logistic Regresison

lm = LogisticRegression()
lm.fit(X_train,y_train)
lm.score(X_test,y_test)*100
# Out:
# 87.70833333333333

# %%
# Gradient Boosting

gb = GradientBoostingClassifier()
gb.fit(X_train,y_train)
gb.score(X_test,y_test)*100
# Out:
# 86.25

# %%
# Decision Tree

dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
dt.score(X_test,y_test)*100
# Out:
# 84.375

# %%
#Stochastic Gradient Decent Classifier

sgd = SGDClassifier(penalty=None)
sgd.fit(X_train, y_train)
sgd.score(X_test,y_test)*100
# Out:
# 86.875

# %%
# ------------Try to increase accuracy of models by using cross validation-------------

# CV for Random Forest
rf_cv = cross_val_score(rf, X_train, y_train, cv =10)
rf_cv.mean()*100
# Out:
# 91.5122265122265

# %%
# Using cross validation with 5 folds,
# Random forest accuracy increased from 87% to 91 %

# %%
# --------------Summary of results---------

# All models accuaracy increased after using Cross validation
# With Random forest having the highest accuaracy of 91%
# We select this model as the best model to predict wine quality and the features
# important in predicting wine quality

# %%
#ROC CURVES FOR THE MODEL
probs = rf.predict_proba(X_test)  #for random forest model (NB: not rf_cv)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
